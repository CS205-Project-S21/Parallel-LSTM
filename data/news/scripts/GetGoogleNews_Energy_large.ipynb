# %%
import sys
import pandas as pd
sys.path.append("../utils/")
from fetchgooglenews import GoogleNews
from fetchcontextweb import fetch_context_web
import datetime
import math
import time

# %%
startdate = datetime.date(2016,3,31)
enddate = datetime.date(2021,4,16)

# %%
def generate_periods(startdate, enddate, length=30, shift=-1):
    totaldays = (enddate - startdate).days + 1
    num_periods = math.ceil(totaldays/length)
    output_dates = []
    for i in range(0, num_periods):
        if i < num_periods-1:
            leftdate = startdate + datetime.timedelta(days=i*length)
            rightdate = startdate + datetime.timedelta(days=((i+1)*length+shift))
        else:
            leftdate = startdate + datetime.timedelta(days=i*length)
            rightdate = enddate
        leftdate_str = datetime.date.strftime(leftdate, "%m/%d/%Y")
        rightdate_str = datetime.date.strftime(rightdate, "%m/%d/%Y")
        output_dates.append((leftdate_str, rightdate_str))
    return output_dates

# %%
def get_news(keywords, time_periods, outname, MAX_PAGE=5, duplicate=True, pause=1):
    # Download news by scrapping google search news section
    results_all = []
    count = 0
    for leftdate, rightdate in time_periods:
        # Duplicate will copy same article twice, and set one at 4am one at 12pm
        googlenews = GoogleNews(lang='en', start=leftdate,end=rightdate, numperpage=50, duplicate=duplicate)
        googlenews.search(keywords)
        for i in range(2,MAX_PAGE+1):
            time.sleep(pause)
            googlenews.get_page(i)
            if googlenews.failflag() == 1:
                break
        results_all.extend(googlenews.results())
        print("Finish Request from {} to {}, Get {} articles".format(leftdate, rightdate, len(googlenews.results())))
        time.sleep(10)
        count += 1
        if count % 10 == 0:
            pd.DataFrame(results_all).to_csv(outname.format(count//10))
            print("Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period {}".format(count//10))
            time.sleep(2000)
    return results_all

# %%
def get_news_cw(keywords, time_periods, MAX_PAGE=5):
    # Download news by scrapping google search news section
    results_all = []
    
    for leftdate, rightdate in time_periods:
        results_period = []
        
        for i in range(1,MAX_PAGE+1):
            tmp_results, fail_flag = fetch_context_web(keywords, leftdate, rightdate, page=i)
            results_period.extend(tmp_results)
            if fail_flag == 1:
                break
        results_all.extend(results_period)
        print("Finish Request from {} to {}, Get {} articles".format(leftdate, rightdate, len(results_period)))
    return results_all

# %%
timeperiods = generate_periods(startdate, enddate, length=30, shift=-1)

# %% [markdown]
# #### Note
#
# Scrapping google search has some risks. **The best practice is downloading 10 timeperiods at one time with `get_news`, wait for about half an hour, do another 10 timeperiods.**
#
# At maximum, as I tried, we can keep downloading 14 timepriods, then the IP will be blocked for about 2 hour.

# %% [markdown]
# ### Get Energy news

# %%
keyword = 'oil gas energy'
output_file_name= "../data/news_Energy/data/GoogleNews_Energy_large_period_{}.csv"
MAX_PAGE = 5

# %%
timeperiods[-2]
# Out:
# ('03/05/2021', '04/03/2021')

# %%
Energy_news = get_news(keyword,timeperiods[:-2], outname=output_file_name, MAX_PAGE=MAX_PAGE, duplicate=True)
# Out:
# Finish Request from 03/31/2016 to 04/29/2016, Get 496 articles
# Finish Request from 04/30/2016 to 05/29/2016, Get 430 articles
# Finish Request from 05/30/2016 to 06/28/2016, Get 492 articles
# Finish Request from 06/29/2016 to 07/28/2016, Get 496 articles
# Finish Request from 07/29/2016 to 08/27/2016, Get 492 articles
# Finish Request from 08/28/2016 to 09/26/2016, Get 456 articles
# Finish Request from 09/27/2016 to 10/26/2016, Get 478 articles
# Finish Request from 10/27/2016 to 11/25/2016, Get 426 articles
# 'NoneType' object is not iterable
# Finish Request from 11/26/2016 to 12/25/2016, Get 382 articles
# Finish Request from 12/26/2016 to 01/24/2017, Get 498 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 1
# Finish Request from 01/25/2017 to 02/23/2017, Get 496 articles
# Finish Request from 02/24/2017 to 03/25/2017, Get 492 articles
# Finish Request from 03/26/2017 to 04/24/2017, Get 474 articles
# Finish Request from 04/25/2017 to 05/24/2017, Get 500 articles
# Finish Request from 05/25/2017 to 06/23/2017, Get 494 articles
# Finish Request from 06/24/2017 to 07/23/2017, Get 478 articles
# Finish Request from 07/24/2017 to 08/22/2017, Get 494 articles
# Finish Request from 08/23/2017 to 09/21/2017, Get 498 articles
# Finish Request from 09/22/2017 to 10/21/2017, Get 496 articles
# Finish Request from 10/22/2017 to 11/20/2017, Get 494 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 2
# Finish Request from 11/21/2017 to 12/20/2017, Get 500 articles
# Finish Request from 12/21/2017 to 01/19/2018, Get 500 articles
# Finish Request from 01/20/2018 to 02/18/2018, Get 470 articles
# Finish Request from 02/19/2018 to 03/20/2018, Get 500 articles
# Finish Request from 03/21/2018 to 04/19/2018, Get 496 articles
# Finish Request from 04/20/2018 to 05/19/2018, Get 500 articles
# Finish Request from 05/20/2018 to 06/18/2018, Get 482 articles
# Finish Request from 06/19/2018 to 07/18/2018, Get 500 articles
# Finish Request from 07/19/2018 to 08/17/2018, Get 498 articles
# Finish Request from 08/18/2018 to 09/16/2018, Get 478 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 3
# Finish Request from 09/17/2018 to 10/16/2018, Get 498 articles
# Finish Request from 10/17/2018 to 11/15/2018, Get 464 articles
# Finish Request from 11/16/2018 to 12/15/2018, Get 496 articles
# Finish Request from 12/16/2018 to 01/14/2019, Get 500 articles
# Finish Request from 01/15/2019 to 02/13/2019, Get 498 articles
# Finish Request from 02/14/2019 to 03/15/2019, Get 498 articles
# Finish Request from 03/16/2019 to 04/14/2019, Get 488 articles
# Finish Request from 04/15/2019 to 05/14/2019, Get 462 articles
# Finish Request from 05/15/2019 to 06/13/2019, Get 498 articles
# Finish Request from 06/14/2019 to 07/13/2019, Get 500 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 4
# Finish Request from 07/14/2019 to 08/12/2019, Get 500 articles
# Finish Request from 08/13/2019 to 09/11/2019, Get 500 articles
# Finish Request from 09/12/2019 to 10/11/2019, Get 500 articles
# Finish Request from 10/12/2019 to 11/10/2019, Get 500 articles
# Finish Request from 11/11/2019 to 12/10/2019, Get 438 articles
# Finish Request from 12/11/2019 to 01/09/2020, Get 500 articles
# Finish Request from 01/10/2020 to 02/08/2020, Get 500 articles
# Finish Request from 02/09/2020 to 03/09/2020, Get 462 articles
# Finish Request from 03/10/2020 to 04/08/2020, Get 496 articles
# Finish Request from 04/09/2020 to 05/08/2020, Get 450 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 5
# Finish Request from 05/09/2020 to 06/07/2020, Get 488 articles
# 'NoneType' object is not iterable
# Finish Request from 06/08/2020 to 07/07/2020, Get 378 articles
# Finish Request from 07/08/2020 to 08/06/2020, Get 498 articles
# Finish Request from 08/07/2020 to 09/05/2020, Get 500 articles
# 'NoneType' object is not iterable
# Finish Request from 09/06/2020 to 10/05/2020, Get 394 articles
# Finish Request from 10/06/2020 to 11/04/2020, Get 492 articles
# Finish Request from 11/05/2020 to 12/04/2020, Get 500 articles
# Finish Request from 12/05/2020 to 01/03/2021, Get 498 articles
# Finish Request from 01/04/2021 to 02/02/2021, Get 424 articles
# Finish Request from 02/03/2021 to 03/04/2021, Get 500 articles
# Reach 10 requests capacity, will sleep for 2000s. Last batch has been saved as period 6

# %%
df1 = pd.DataFrame(Energy_news)

# %%
df1
# Out:
#                                                    title               source  \
# 0      Senate Passes Legislation Tailored to a Modern...   The New York Times
# 1      Senate Passes Legislation Tailored to a Modern...   The New York Times
# 2      The surprising things Democrats and Republican...  The Washington Post
# 3      The surprising things Democrats and Republican...  The Washington Post
# 4      How Murkowski crafted an energy bill that 80 s...  Alaska Public Media
# ...                                                  ...                  ...
# 28901  Soil Revolution Conference Virtual Presentatio...       Boulder County
# 28902  Boulder County Health Coverage Guides are Here...
# 28903  Boulder County Health Coverage Guides are Here...
# 28904  KRBN ETF Update: Nobel-Prize Winning Economist...
# 28905  KRBN ETF Update: Nobel-Prize Winning Economist...
#
#                     date            datetime  \
# 0           Apr 20, 2016 2016-04-20 04:00:00
# 1           Apr 20, 2016 2016-04-20 12:00:00
# 2      th · Apr 19, 2016 2016-04-19 04:00:00
# 3      th · Apr 19, 2016 2016-04-19 12:00:00
# 4           Apr 20, 2016 2016-04-20 04:00:00
# ...                  ...                 ...
# 28901        Feb 4, 2021 2021-02-04 12:00:00
# 28902        Feb 4, 2021 2021-02-04 04:00:00
# 28903        Feb 4, 2021 2021-02-04 12:00:00
# 28904       Feb 11, 2021 2021-02-11 04:00:00
# 28905       Feb 11, 2021 2021-02-11 12:00:00
#
#                                                     desc  \
# 0      The Senate on Wednesday passed the first broad...
# 1      The Senate on Wednesday passed the first broad...
# 2      Democrats want to fight climate change and fun...
# 3      Democrats want to fight climate change and fun...
# 4      It allows more money for renewable energy rese...
# ...                                                  ...
# 28901  Housing & Energy · Affordable ... Healthy Home...
# 28902  Housing & Energy · Affordable ... Healthy Home...
# 28903  Housing & Energy · Affordable ... Healthy Home...
# 28904  ... Regional Greenhouse Gas Initiative (RGGI)....
# 28905  ... Regional Greenhouse Gas Initiative (RGGI)....
#
#                                                     link
# 0      https://www.nytimes.com/2016/04/21/us/politics...
# 1      https://www.nytimes.com/2016/04/21/us/politics...
# 2      https://www.washingtonpost.com/news/energy-env...
# 3      https://www.washingtonpost.com/news/energy-env...
# 4      https://www.alaskapublic.org/2016/04/20/how-mu...
# ...                                                  ...
# 28901  https://www.bouldercounty.org/news/soil-revolu...
# 28902  https://www.bouldercounty.org/news/boulder-cou...
# 28903  https://www.bouldercounty.org/news/boulder-cou...
# 28904  https://www.prnewswire.com/news-releases/krbn-...
# 28905  https://www.prnewswire.com/news-releases/krbn-...
#
# [28906 rows x 6 columns]

# %%
df1.datetime.max()
# Out:
# Timestamp('2021-03-04 12:00:00')

# %%
df1.to_csv("../data/news_Energy/data/GoogleNews_Energy_large_section1.csv".format(keyword))

# %% [markdown]
# #### Note
#
# It turns out that, on Google search news section, when the publish date is too close to the current date (like 1-2 months ago), the date will show as something like "1 month ago", "3 weeks ago", et al. So it is hard to get exact publish date through current scrap tools. **The best practice is to stop at some time earlier and use another News API to download recent articles.**
#
# So I will drop articles later than 03/04/2021 and download articles from 03/05/2021 to 04/16/2021 by News APIs.

# %% [markdown]
# #### Use context web search API to download recent News

# %%
recent_periods = generate_periods(datetime.date(2021,3,5), datetime.date(2021,4,17), length=10, shift=0)

# %%
recent_periods
# Out:
# [('03/05/2021', '03/15/2021'),
#  ('03/15/2021', '03/25/2021'),
#  ('03/25/2021', '04/04/2021'),
#  ('04/04/2021', '04/14/2021'),
#  ('04/14/2021', '04/17/2021')]

# %%
Energy_news2 = get_news_cw(keyword, recent_periods, MAX_PAGE=5)
# Out:
# Finish Request from 03/05/2021 to 03/15/2021, Get 200 articles
# Finish Request from 03/15/2021 to 03/25/2021, Get 147 articles
# Finish Request from 03/25/2021 to 04/04/2021, Get 235 articles
# Finish Request from 04/04/2021 to 04/14/2021, Get 250 articles
# Finish Request from 04/14/2021 to 04/17/2021, Get 243 articles

# %%
df2 = pd.DataFrame(Energy_news2)

# %%
df2
# Out:
#                                                   title           source  \
# 0     Guest Opinion: An update on the oil and gas in...  fortmorgantimes
# 1     Work continues to preserve NM's oil and gas in...     currentargus
# 2     Oil and gas industry touts value of Permian Ba...     currentargus
# 3     ONGC's share in India's oil, gas production ju...       indiatimes
# 4     Your turn: Oil and gas production ban could hu...  demingheadlight
# ...                                                 ...              ...
# 1070  Oil posts highest finish since mid-March on a ...      marketwatch
# 1071  3 Energy Stocks Set to Soar When American Oil ...             fool
# 1072  Oil Prices: Is Another Tumble in the Forecast?...             fool
# 1073  Oil climbs nearly 5% on signs of increasing cr...          reuters
# 1074  U.S. Shale Oil Output Rising, Permian to Hit 1...            zacks
#
#               date            datetime  \
# 0     Mar 14, 2021 2021-03-14 21:41:11
# 1     Mar 14, 2021 2021-03-14 15:42:01
# 2     Mar 14, 2021 2021-03-14 12:21:00
# 3     Mar 14, 2021 2021-03-14 11:14:00
# 4     Mar 14, 2021 2021-03-14 11:02:00
# ...            ...                 ...
# 1070  Apr 14, 2021 2021-04-14 11:30:00
# 1071  Apr 14, 2021 2021-04-14 10:00:00
# 1072  Apr 14, 2021 2021-04-14 08:09:00
# 1073  Apr 14, 2021 2021-04-14 08:09:00
# 1074  Apr 14, 2021 2021-04-14 00:00:00
#
#                                                    desc  \
# 0     Crude oil prices are rising again, as OPEC+ ha...
# 1     Sen. Martin Heinrich and Ben Ray Lujn both urg...
# 2     Activists worried all that economic opportunit...
# 3     While Oil and Natural Gas Corporation (ONGC) m...
# 4     "Your turn" is a guest column format View Comm...
# ...                                                 ...
# 1070  Oil futures end sharply higher on Wednesday, a...
# 1071  Learn about 3 undervalued oil stocks that are ...
# 1072  The International Energy Agencys latest foreca...
# 1073  [   "Oil prices surged almost 5% on Wednesday,...
# 1074  With oil prices having rebounded to around $60...
#
#                                                    link
# 0     https://www.fortmorgantimes.com/2021/03/14/gue...
# 1     https://www.currentargus.com/story/opinion/col...
# 2     https://www.currentargus.com/story/news/local/...
# 3     https://energy.economictimes.indiatimes.com/ne...
# 4     https://www.demingheadlight.com/story/opinion/...
# ...                                                 ...
# 1070  https://www.marketwatch.com/story/oil-prices-j...
# 1071  https://www.fool.com/investing/general/2015/05...
# 1072  https://www.fool.com/investing/2017/11/19/oil-...
# 1073  https://www.reuters.com/business/energy/oil-ri...
# 1074  https://www.zacks.com/stock/news/1394622/us-sh...
#
# [1075 rows x 6 columns]

# %%
df2_short = df2[df2.datetime < datetime.datetime(2021,4,17,0,0)]

# %%
df2_short.datetime.max()
# Out:
# Timestamp('2021-04-16 23:28:49')

# %%
df2_short.to_csv("../data/news_Energy/data/GoogleNews_Energy_large_section2.csv")

# %% [markdown]
# #### Combine the news from different sections

# %%
dateframe_all = pd.concat([df1,df2_short])

# %%
dateframe_all.sort_values(by=['datetime'], inplace=True)

# %%
dateframe_test = dateframe_all.drop_duplicates()

# %%
dateframe_test
# Out:
#                                                   title  \
# 136   Deep in the Heart of Texas… Methane is Leaking...
# 214   Black Thursday: Layoffs hit 500 Wyoming coal m...
# 32    As U.S. shale drillers suffer, even the bankru...
# 480   DTE Energy's Appliance Recycling Program puts ...
# 170   BP, China's Top Producer to Develop Unconventi...
# ...                                                 ...
# 833   EXCLUSIVE Nigeria refines energy reform bill t...
# 973   The Market Bloodbath: A Boon for Oil and Gas -...
# 832   Kodiak Oil & Gas' Year in Review -- The Motley...
# 972   Qatar- QFRDI develops new method to fight corr...
# 1057  IN BRIEF: Nat. gas company hit with consumer c...
#
#                                            source          date  \
# 136   News and blogs | Environmental Defense Fund  Mar 31, 2016
# 214                                                Mar 31, 2016
# 32                                        Reuters  Mar 31, 2016
# 480                                                Mar 31, 2016
# 170                      Natural Gas Intelligence  Mar 31, 2016
# ...                                           ...           ...
# 833                                  oilandgas360  Apr 16, 2021
# 973                                          fool  Apr 16, 2021
# 832                                          fool  Apr 16, 2021
# 972                                        menafn  Apr 16, 2021
# 1057                                      reuters  Apr 16, 2021
#
#                 datetime                                               desc  \
# 136  2016-03-31 04:00:00  And, methane pollution, at its core, is wasted...
# 214  2016-03-31 04:00:00  Peabody Energy cut 235 miners, and Arch Coal c...
# 32   2016-03-31 04:00:00  More than 50 North American oil and gas produc...
# 480  2016-03-31 04:00:00  DETROIT, March 31, 2016 /PRNewswire/ -- DTE En...
# 170  2016-03-31 04:00:00  The companies also agreed to share knowledge o...
# ...                  ...                                                ...
# 833  2021-04-16 22:30:36  The latest oil and gas news, dedicated to all ...
# 973  2021-04-16 23:00:00  Following Benjamin Graham's ideas is all that ...
# 832  2021-04-16 23:00:00  A look back at a strong year for the Denver oi...
# 972  2021-04-16 23:04:25  Qatar Foundation Research, Development, and In...
# 1057 2021-04-16 23:28:49  A Texas-based rose merchant filed a proposed c...
#
#                                                    link
# 136   https://blogs.edf.org/energyexchange/2016/03/3...
# 214   https://www.wyofile.com/black-thursday-layoffs...
# 32    https://www.reuters.com/article/us-usa-energy-...
# 480   https://www.prnewswire.com/news-releases/dte-e...
# 170   https://www.naturalgasintel.com/bp-chinas-top-...
# ...                                                 ...
# 833   https://www.oilandgas360.com/exclusive-nigeria...
# 973   https://www.fool.com/investing/general/2011/08...
# 832   https://www.fool.com/investing/general/2011/12...
# 972   https://menafn.com/1101931382/Qatar-QFRDI-deve...
# 1057  https://www.reuters.com/article/usa-energy-law...
#
# [29905 rows x 6 columns]

# %%
dateframe_test.to_csv("../data/news_Energy/data/GoogleNews_Energy_large_all.csv", index=False)
